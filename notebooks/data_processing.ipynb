# %%
# -------------------------------
# Step 0: Imports and Path Setup
# -------------------------------
import os
import sys
import pandas as pd

# Notebook is in the project root (bnpl_risk)
project_root = os.getcwd()
print("Project root:", project_root)

# Add src folder to sys.path for imports
src_path = os.path.join(project_root, "src")
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# Import your functions from data_processing.py
from data_processing import process_data, split_data

# Paths to data
raw_data_path = os.path.join(project_root, "data", "raw", "data.csv")
processed_data_path = os.path.join(project_root, "data", "processed", "processed_data.csv")

print("Raw data path:", raw_data_path)
print("Processed data path:", processed_data_path)
# Out:
# Project root: C:\Users\derej\Desktop\Kifya\bnpl_risk
# Raw data path: C:\Users\derej\Desktop\Kifya\bnpl_risk\data\raw\data.csv
# Processed data path: C:\Users\derej\Desktop\Kifya\bnpl_risk\data\processed\processed_data.csv

# %%
# -------------------------------
# Step 1: Process Raw Data
# -------------------------------
# Process raw CSV and save processed CSV
df_processed = process_data(input_path=raw_data_path, output_path=processed_data_path)

# Quick check
print("Processed data shape:", df_processed.shape)
df_processed.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\derej\Desktop\Kifya\bnpl_risk\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
raw_data_path = os.path.join(project_root, "bnpl_risk", "data", "raw", "data.csv")
